# %%
import pandas as pd
ds=pd.read_csv(r'C:\Users\91739\Downloads\Bipolar.csv')
ds.head()
# Out:
#    ID  Felt alone  felt stressed  feeling sad  being myself  hard to have fun  \
# 0   1           3              3            3             4                 4
# 1   2           3              3            3             3                 4
# 2   3           5              3            1             3                 3
# 3   4           1              1            1             1                 1
# 4   5           3              4            3             3                 3
#
#    easily annoyed  short temper  freq anger  lose temper  ...  Stomach pain  \
# 0               3             5           5            3  ...             3
# 1               5             5           1            3  ...             5
# 2               1             3           5            3  ...             3
# 3               1             5           3            3  ...             1
# 4               5             3           1            3  ...             3
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       33 non-null     int64
#  1   Felt alone               33 non-null     int64
#  2   felt stressed            33 non-null     int64
#  3   feeling sad              33 non-null     int64
#  4   being myself             33 non-null     int64
#  5   hard to have fun         33 non-null     int64
#  6   easily annoyed           33 non-null     int64
#  7   short temper             33 non-null     int64
#  8   freq anger               33 non-null     int64
#  9   lose temper              33 non-null     int64
#  10  irritability             33 non-null     int64
#  11  qnconfident              33 non-null     int64
#  12  qnsleep                  33 non-null     int64
#  13  qntalk                   33 non-null     int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds['Gender']=le.fit_transform(ds['Gender'])
ds['Gender']=pd.DataFrame(ds['Gender'])

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       33 non-null     int64
#  1   Felt alone               33 non-null     int64
#  2   felt stressed            33 non-null     int64
#  3   feeling sad              33 non-null     int64
#  4   being myself             33 non-null     int64
#  5   hard to have fun         33 non-null     int64
#  6   easily annoyed           33 non-null     int64
#  7   short temper             33 non-null     int64
#  8   freq anger               33 non-null     int64
#  9   lose temper              33 non-null     int64
#  10  irritability             33 non-null     int64
#  11  qnconfident              33 non-null     int64
#  12  qnsleep                  33 non-null     int64
#  13  qntalk                   33 non-null     int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as mp
cols=ds.iloc[0:32]
ds = pd.DataFrame(ds, columns=cols)
y=ds.iloc[:,1:30]
# plot the dataframe
ds.plot(x="ID", y=y, kind="bar", figsize=(9, 8))
 
# print bar graph
mp.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-d3992b64fc13> in <module>
#       2 import matplotlib.pyplot as mp
#       3 cols=ds.iloc[0:32]
# ----> 4 ds = pd.DataFrame(ds, columns=cols)
#       5 y=ds.iloc[:,1:30]
#       6 # plot the dataframe
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     522                 return
#     523
# --> 524             mgr = self._init_mgr(
#     525                 data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     526             )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _init_mgr(cls, mgr, axes, dtype, copy)
#     209         for a, axe in axes.items():
#     210             if axe is not None:
# --> 211                 axe = ensure_index(axe)
#     212                 bm_axis = cls._get_block_manager_axis(a)
# ...

# %%
cols=ds.iloc[0:32]

# %%
cols
# Out:
#     ID  Felt alone  felt stressed  feeling sad  being myself  \
# 0    1           3              3            3             4
# 1    2           3              3            3             3
# 2    3           5              3            1             3
# 3    4           1              1            1             1
# 4    5           3              4            3             3
# 5    6           1              1            1             3
# 6    7           4              4            3             3
# 7    8           3              3            3             3
# 8    9           1              1            1             3
# 9   10           1              3            1             3
# 10  11           1              3            1             4
# 11  12           4              5            5             4
# 12  13           1              1            1             1
# 13  14           1              1            1             1
# ...
